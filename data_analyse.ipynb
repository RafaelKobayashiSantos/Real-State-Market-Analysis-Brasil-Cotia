# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel("dados_imoveis_pby.xlsx")

df['tipo de imóvel'] = df['descricao'].str.split(' ').str[0]

# %%
display(df.isnull().sum())
# Out:
# descricao          0
# preco              1
# area               0
# quartos            1
# banheiros          0
# vagas             47
# tipo de imóvel     0
# preco_m2           1
# bairro             0
# cidade             0
# dtype: int64
